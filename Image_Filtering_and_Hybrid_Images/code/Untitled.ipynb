# %%
# %run my_imfilter.py

# %%
# %run gauss2D.py

# %%
# %run proj1.py
# Out:
# C:\Users\Administrator\Desktop\proj1\code\proj1.py:84: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   cur_image = imresize(cur_image, scale_factor, 'bilinear').astype(np.float)/255

# %%
# %run proj1.py
# Out:
# C:\Users\Administrator\Desktop\proj1\code\proj1.py:84: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   cur_image = imresize(cur_image, scale_factor, 'bilinear').astype(np.float)/255

# %%
# %run proj1.py
# Out:
# C:\Users\Administrator\Desktop\proj1\code\proj1.py:84: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   cur_image = imresize(cur_image, scale_factor, 'bilinear').astype(np.float)/255

# %%
# %run proj1.py
# Out:
# C:\Users\Administrator\Desktop\proj1\code\proj1.py:84: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   cur_image = imresize(cur_image, scale_factor, 'bilinear').astype(np.float)/255

# %%
# %run proj1.py
# Out:
# C:\Users\Administrator\Desktop\proj1\code\proj1.py:84: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   cur_image = imresize(cur_image, scale_factor, 'bilinear').astype(np.float)/255

# %%
# %run basiccontrasttest.py
# Out:
# C:\Users\Administrator\Desktop\proj1\code\basiccontrasttest.py:16: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   test_image = imresize(test_image,0.7,'bilinear')

# %%
# %run proj1_test_filtering.py
# Out:
# done
